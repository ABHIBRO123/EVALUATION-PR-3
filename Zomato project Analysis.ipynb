# %%
Zomato Restaurant
Project Description
Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
cuisines of every part of the world which lies in their budget. This analysis is also for those who
want to find the value for money restaurants in various parts of the country for the cuisines.
Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
the country and which locality of that country serves that cuisines with maximum number of
restaurants.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Load datasets
country_code_df = pd.read_excel("https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Fraw.githubusercontent.com%2FFlipRoboTechnologies%2FML_-Datasets%2Fmain%2FZ_Restaurant%2FCountry-Code.xlsx&wdOrigin=BROWSELINK")
zomato_df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # Load datasets
# ----> 4 country_code_df = pd.read_excel("https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Fraw.githubusercontent.com%2FFlipRoboTechnologies%2FML_-Datasets%2Fmain%2FZ_Restaurant%2FCountry-Code.xlsx&wdOrigin=BROWSELINK")
#       5 zomato_df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Load datasets using direct links to the raw files
country_code_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx"
zomato_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv"

# Read the Excel and CSV files
country_code_df = pd.read_excel(country_code_url)
zomato_df = pd.read_csv(zomato_url)

# Display the first few rows of each dataframe to understand their structures
print(country_code_df.head())
print(zomato_df.head())

# Assuming the common column is 'Country Code' in both datasets
# Check for exact column names and adjust if necessary
merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')

# Save the merged dataset to a new CSV file
merged_df.to_csv("merged_zomato_country.csv", index=False)

# Display the first few rows of the merged dataframe
print(merged_df.head())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 9
#       7 # Read the Excel and CSV files
#       8 country_code_df = pd.read_excel(country_code_url)
# ----> 9 zomato_df = pd.read_csv(zomato_url)
#      11 # Display the first few rows of each dataframe to understand their structures
#      12 print(country_code_df.head())
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load datasets using direct links to the raw files
country_code_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx"
zomato_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv"

# Read the Excel file
country_code_df = pd.read_excel(country_code_url)

# Read the CSV file with a specified encoding
zomato_df = pd.read_csv(zomato_url, encoding='ISO-8859-1')

# Display the first few rows of each dataframe to understand their structures
print(country_code_df.head())
print(zomato_df.head())

# Assuming the common column is 'Country Code' in both datasets
# Check for exact column names and adjust if necessary
merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')

# Save the merged dataset to a new CSV file
merged_df.to_csv("merged_zomato_country.csv", index=False)

# Display the first few rows of the merged dataframe
print(merged_df.head())
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
ANALYSIS:--

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# URLs for the datasets
country_code_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx"
zomato_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv"

# Load the datasets
country_code_df = pd.read_excel(country_code_url)
zomato_df = pd.read_csv(zomato_url, encoding='ISO-8859-1')

# Display the first few rows to understand their structures
print("Country Code DataFrame:")
print(country_code_df.head())

print("\nZomato DataFrame:")
print(zomato_df.head())

# Check the column names of both dataframes
print("\nCountry Code DataFrame Columns:")
print(country_code_df.columns)

print("\nZomato DataFrame Columns:")
print(zomato_df.columns)

# Assuming the common column is 'Country Code' in both datasets
# Rename columns if necessary to match the column names for merging
if 'Country Code' in country_code_df.columns and 'Country Code' in zomato_df.columns:
    merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')
else:
    print("Common column 'Country Code' not found in both dataframes.")
    # Adjust the column names to match for merging
    # Example (adjust based on actual column names):
    # country_code_df.rename(columns={'<original_column_name_in_country_code>': 'Country Code'}, inplace=True)
    # zomato_df.rename(columns={'<original_column_name_in_zomato>': 'Country Code'}, inplace=True)
    # merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')

# Save the merged dataset to a new CSV file if merging was successful
if 'merged_df' in locals():
    merged_df.to_csv("merged_zomato_country.csv", index=False)
    # Display the first few rows of the merged dataframe
    print("\nMerged DataFrame:")
    print(merged_df.head())
else:
    print("Merging was not performed due to missing common column.")
# Out:
# Country Code DataFrame:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
#
# Zomato DataFrame:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# URLs for the datasets
country_code_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx"
zomato_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv"

# Load the datasets
country_code_df = pd.read_excel(country_code_url)
zomato_df = pd.read_csv(zomato_url, encoding='ISO-8859-1')

# Display the first few rows to understand their structures
print("Country Code DataFrame:")
print(country_code_df.head())

print("\nZomato DataFrame:")
print(zomato_df.head())

# Check the column names of both dataframes
print("\nCountry Code DataFrame Columns:")
print(country_code_df.columns)

print("\nZomato DataFrame Columns:")
print(zomato_df.columns)

# Assuming the common column is 'Country Code' in both datasets
# Rename columns if necessary to match the column names for merging
if 'Country Code' in country_code_df.columns and 'Country Code' in zomato_df.columns:
    merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')
else:
    print("Common column 'Country Code' not found in both dataframes.")
    # Example adjustment (if necessary):
    # country_code_df.rename(columns={'<original_column_name_in_country_code>': 'Country Code'}, inplace=True)
    # zomato_df.rename(columns={'<original_column_name_in_zomato>': 'Country Code'}, inplace=True)
    # merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')

# Save the merged dataset to a new CSV file if merging was successful
if 'merged_df' in locals():
    merged_df.to_csv("merged_zomato_country.csv", index=False)
    # Display the first few rows of the merged dataframe
    print("\nMerged DataFrame:")
    print(merged_df.head())
else:
    print("Merging was not performed due to missing common column.")
# Out:
# Country Code DataFrame:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
#
# Zomato DataFrame:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# URLs for the datasets
country_code_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx"
zomato_url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv"

# Load the datasets
country_code_df = pd.read_excel(country_code_url)
zomato_df = pd.read_csv(zomato_url, encoding='ISO-8859-1')

# Display the first few rows to understand their structures
print("Country Code DataFrame:")
print(country_code_df.head())

print("\nZomato DataFrame:")
print(zomato_df.head())

# Check the column names and data types of both dataframes
print("\nCountry Code DataFrame Columns and Data Types:")
print(country_code_df.columns)
print(country_code_df.dtypes)

print("\nZomato DataFrame Columns and Data Types:")
print(zomato_df.columns)
print(zomato_df.dtypes)

# Assuming the common column is 'Country Code' in both datasets
# Rename columns if necessary to match the column names for merging
if 'Country Code' in country_code_df.columns and 'Country Code' in zomato_df.columns:
    merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')
else:
    print("Common column 'Country Code' not found in both dataframes.")
    # Example adjustment (if necessary):
    # country_code_df.rename(columns={'<original_column_name_in_country_code>': 'Country Code'}, inplace=True)
    # zomato_df.rename(columns={'<original_column_name_in_zomato>': 'Country Code'}, inplace=True)
    # merged_df = pd.merge(zomato_df, country_code_df, on='Country Code', how='inner')

# Save the merged dataset to a new CSV file if merging was successful
if 'merged_df' in locals():
    merged_df.to_csv("merged_zomato_country.csv", index=False)
    # Display the first few rows of the merged dataframe
    print("\nMerged DataFrame:")
    print(merged_df.head())
else:
    print("Merging was not performed due to missing common column.")
# Out:
# Country Code DataFrame:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
#
# Zomato DataFrame:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# ...
